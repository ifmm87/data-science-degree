# %%
import numpy as np 
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
data = pd.read_excel('Online Retail.xlsx')
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Exploring the different regions of transactions 
data.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
data.shape
# Out:
# (541909, 8)

# %%
# Stripping extra spaces in the description 
data['Description'] = data['Description'].str.strip() 

# Dropping the rows without any invoice number 
data.dropna(axis = 0, subset =['InvoiceNo'], inplace = True) 
data['InvoiceNo'] = data['InvoiceNo'].astype('str') 

# Dropping all transactions which were done on credit 
data = data[~data['InvoiceNo'].str.contains('C')]

# %%
data.shape
# Out:
# (532621, 8)

# %%
# Transactions done in France 
basket_France = (data[data['Country'] =="France"] 
        .groupby(['InvoiceNo', 'Description'])['Quantity'] 
        .sum().unstack().reset_index().fillna(0) 
        .set_index('InvoiceNo')) 

# Transactions done in the United Kingdom 
basket_UK = (data[data['Country'] =="United Kingdom"] 
        .groupby(['InvoiceNo', 'Description'])['Quantity'] 
        .sum().unstack().reset_index().fillna(0) 
        .set_index('InvoiceNo')) 

# Transactions done in Portugal 
basket_Por = (data[data['Country'] =="Portugal"] 
        .groupby(['InvoiceNo', 'Description'])['Quantity'] 
        .sum().unstack().reset_index().fillna(0) 
        .set_index('InvoiceNo')) 

basket_Sweden = (data[data['Country'] =="Sweden"] 
        .groupby(['InvoiceNo', 'Description'])['Quantity'] 
        .sum().unstack().reset_index().fillna(0) 
        .set_index('InvoiceNo'))

# %%
basket_France.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# 536852                                 0.0
# 536974                                 0.0
# 537065                                 0.0
# 537463                                 0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536370                                       0.0                          0.0
# 536852                                       0.0                          0.0
# 536974                                       0.0                          0.0
# 537065                                       0.0                          0.0
# 537463                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                             0.0                                 0.0
# 536852                             0.0                                 0.0
# 536974                             0.0                                 0.0
# 537065                             0.0                                 0.0
# 537463                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo                                   ...
# 536370                                 0.0  ...                          0.0
# 536852                                 0.0  ...                          0.0
# 536974                                 0.0  ...                          0.0
# 537065                                 0.0  ...                          0.0
# 537463                                 0.0  ...                          0.0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                  0.0                              0.0
# 536852                                  0.0                              0.0
# 536974                                  0.0                              0.0
# 537065                                  0.0                              0.0
# 537463                                  0.0                              0.0
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536370                           0.0                        0.0
# 536852                           0.0                        0.0
# 536974                           0.0                        0.0
# 537065                           0.0                        0.0
# 537463                           0.0                        0.0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 536370                             0.0                         0.0
# 536852                             0.0                         0.0
# 536974                             0.0                         0.0
# 537065                             0.0                         0.0
# 537463                             0.0                         0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536370                               0.0                             0.0
# 536852                               0.0                             0.0
# 536974                               0.0                             0.0
# 537065                               0.0                             0.0
# 537463                               0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                   0.0
# 536852                                   0.0
# 536974                                   0.0
# 537065                                   0.0
# 537463                                   0.0
#
# [5 rows x 1563 columns]

# %%
basket_France.shape
# Out:
# (392, 1563)

# %%
# Defining the hot encoding function to make the data suitable 
# for the concerned libraries 
def hot_encode(x): 
    if(x<= 0): 
        return 0
    if(x>= 1): 
        return 1

# Encoding the datasets 
basket_encoded = basket_France.applymap(hot_encode) 
basket_France = basket_encoded 

basket_encoded = basket_UK.applymap(hot_encode) 
basket_UK = basket_encoded 

basket_encoded = basket_Por.applymap(hot_encode) 
basket_Por = basket_encoded 

basket_encoded = basket_Sweden.applymap(hot_encode) 
basket_Sweden = basket_encoded

# %%
# Building the model 
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True) 

# Collecting the inferred rules in a dataframe 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules.head()
# Out:
#                                            antecedents  \
# 44                        (JUMBO BAG WOODLAND ANIMALS)
# 258  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 270  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 300  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 301  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
#
#                          consequents  antecedent support  consequent support  \
# 44                         (POSTAGE)            0.076531            0.765306
# 258                        (POSTAGE)            0.051020            0.765306
# 270                        (POSTAGE)            0.053571            0.765306
# 300  (SET/6 RED SPOTTY PAPER PLATES)            0.102041            0.127551
# 301    (SET/6 RED SPOTTY PAPER CUPS)            0.102041            0.137755
#
#       support  confidence      lift  leverage  conviction
# 44   0.076531       1.000  1.306667  0.017961         inf
# 258  0.051020       1.000  1.306667  0.011974         inf
# 270  0.053571       1.000  1.306667  0.012573         inf
# 300  0.099490       0.975  7.644000  0.086474   34.897959
# 301  0.099490       0.975  7.077778  0.085433   34.489796

# %%
basket_France.shape
# Out:
# (392, 1563)

# %%
frq_items = apriori(basket_UK, min_support = 0.03, use_colnames = True) 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules.head()
# Out:
#                          antecedents                        consequents  \
# 3   (PINK REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 4  (GREEN REGENCY TEACUP AND SAUCER)  (ROSES REGENCY TEACUP AND SAUCER)
# 5  (ROSES REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 9          (JUMBO BAG PINK POLKADOT)          (JUMBO BAG RED RETROSPOT)
# 1       (ALARM CLOCK BAKELIKE GREEN)         (ALARM CLOCK BAKELIKE RED)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 3            0.037660            0.050035  0.030910    0.820768  16.403939
# 4            0.050035            0.051267  0.037553    0.750535  14.639752
# 5            0.051267            0.050035  0.037553    0.732497  14.639752
# 9            0.062088            0.103820  0.042053    0.677308   6.523895
# 1            0.046928            0.049821  0.030160    0.642694  12.900183
#
#    leverage  conviction
# 3  0.029026    5.300203
# 4  0.034988    3.803076
# 5  0.034988    3.551237
# 9  0.035607    2.777201
# 1  0.027822    2.659288

# %%
basket_UK.shape
# Out:
# (18667, 4175)

# %%
frq_items = apriori(basket_Por, min_support = 0.05, use_colnames = True) 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules.head()
# Out:
#                              antecedents                          consequents  \
# 1170  (SET 12 COLOUR PENCILS DOLLY GIRL)     (SET 12 COLOUR PENCILS SPACEBOY)
# 1171    (SET 12 COLOUR PENCILS SPACEBOY)   (SET 12 COLOUR PENCILS DOLLY GIRL)
# 1172  (SET 12 COLOUR PENCILS DOLLY GIRL)   (SET OF 4 KNICK KNACK TINS LONDON)
# 1173  (SET OF 4 KNICK KNACK TINS LONDON)   (SET 12 COLOUR PENCILS DOLLY GIRL)
# 1174  (SET 12 COLOUR PENCILS DOLLY GIRL)  (SET OF 4 KNICK KNACK TINS POPPIES)
#
#       antecedent support  consequent support   support  confidence       lift  \
# 1170            0.051724            0.051724  0.051724         1.0  19.333333
# 1171            0.051724            0.051724  0.051724         1.0  19.333333
# 1172            0.051724            0.051724  0.051724         1.0  19.333333
# 1173            0.051724            0.051724  0.051724         1.0  19.333333
# 1174            0.051724            0.051724  0.051724         1.0  19.333333
#
#       leverage  conviction
# 1170  0.049049         inf
# 1171  0.049049         inf
# 1172  0.049049         inf
# 1173  0.049049         inf
# 1174  0.049049         inf

# %%
frq_items = apriori(basket_Sweden, min_support = 0.05, use_colnames = True) 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules.head()
# Out:
#                         antecedents                        consequents  \
# 0     (12 PENCILS SMALL TUBE SKULL)      (PACK OF 72 SKULL CAKE CASES)
# 1     (PACK OF 72 SKULL CAKE CASES)      (12 PENCILS SMALL TUBE SKULL)
# 4    (ASSORTED BOTTLE TOP  MAGNETS)            (36 DOILIES DOLLY GIRL)
# 5           (36 DOILIES DOLLY GIRL)     (ASSORTED BOTTLE TOP  MAGNETS)
# 180  (CHILDRENS CUTLERY DOLLY GIRL)  (CHILDRENS CUTLERY CIRCUS PARADE)
#
#      antecedent support  consequent support   support  confidence  lift  \
# 0              0.055556            0.055556  0.055556         1.0  18.0
# 1              0.055556            0.055556  0.055556         1.0  18.0
# 4              0.055556            0.055556  0.055556         1.0  18.0
# 5              0.055556            0.055556  0.055556         1.0  18.0
# 180            0.055556            0.055556  0.055556         1.0  18.0
#
#      leverage  conviction
# 0    0.052469         inf
# 1    0.052469         inf
# 4    0.052469         inf
# 5    0.052469         inf
# 180  0.052469         inf

# %%
rules.shape
# Out:
# (104608, 9)

# %%
rules.columns
# Out:
# Index(['antecedents', 'consequents', 'antecedent support',
#        'consequent support', 'support', 'confidence', 'lift', 'leverage',
#        'conviction'],
#       dtype='object')

# %%
rules[300:350]
# Out:
#                                             antecedents  \
# 2587                      (LARGE RED BABUSHKA NOTEBOOK)
# 2589                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2590  (LARGE RED BABUSHKA NOTEBOOK, SET OF 3 CAKE TI...
# 2592  (SET OF 3 CAKE TINS SKETCHBOOK, LARGE YELLOW B...
# 2593                      (LARGE RED BABUSHKA NOTEBOOK)
# 2595                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2596  (LARGE RED BABUSHKA NOTEBOOK, VICTORIAN SEWING...
# 2598  (LARGE YELLOW BABUSHKA NOTEBOOK, VICTORIAN SEW...
# 2599                      (LARGE RED BABUSHKA NOTEBOOK)
# 2601                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2610  (PACK OF 12 TRADITIONAL CRAYONS, MAGIC DRAWING...
# 2611                      (LARGE RED BABUSHKA NOTEBOOK)
# 2622  (SET OF 3 CAKE TINS SKETCHBOOK, MAGIC DRAWING ...
# 2623                      (LARGE RED BABUSHKA NOTEBOOK)
# 2634  (PACK OF 12 TRADITIONAL CRAYONS, MAGIC DRAWING...
# 2635                      (LARGE RED BABUSHKA NOTEBOOK)
# 2646  (SET OF 3 CAKE TINS SKETCHBOOK, MAGIC DRAWING ...
# 2647                      (LARGE RED BABUSHKA NOTEBOOK)
# 2658  (PACK OF 12 TRADITIONAL CRAYONS, SET OF 3 CAKE...
# 2659                      (LARGE RED BABUSHKA NOTEBOOK)
# 2670  (PACK OF 12 TRADITIONAL CRAYONS, VICTORIAN SEW...
# 2671                      (LARGE RED BABUSHKA NOTEBOOK)
# 2676  (SET OF 3 CAKE TINS SKETCHBOOK, SET OF 3 CAKE ...
# 2677                      (LARGE RED BABUSHKA NOTEBOOK)
# 2688  (SET OF 3 CAKE TINS SKETCHBOOK, VICTORIAN SEWI...
# 2689                      (LARGE RED BABUSHKA NOTEBOOK)
# 2700  (PACK OF 12 TRADITIONAL CRAYONS, MAGIC DRAWING...
# 2701                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2712  (SET OF 3 CAKE TINS SKETCHBOOK, MAGIC DRAWING ...
# 2713                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2724  (PACK OF 12 TRADITIONAL CRAYONS, MAGIC DRAWING...
# 2725                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2736  (SET OF 3 CAKE TINS SKETCHBOOK, MAGIC DRAWING ...
# 2737                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2748  (PACK OF 12 TRADITIONAL CRAYONS, SET OF 3 CAKE...
# 2749                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2760  (PACK OF 12 TRADITIONAL CRAYONS, VICTORIAN SEW...
# 2761                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2766  (SET OF 3 CAKE TINS SKETCHBOOK, SET OF 3 CAKE ...
# 2767                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2778  (SET OF 3 CAKE TINS SKETCHBOOK, VICTORIAN SEWI...
# 2779                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2788      (POSTAGE, ROUND SNACK BOXES SET OF4 WOODLAND)
# 2793                 (LUNCH BOX WITH CUTLERY RETROSPOT)
# 3227  (PACK OF 60 SPACEBOY CAKE CASES, MINI PLAYING ...
# 3230                   (SET 12 COLOUR PENCILS SPACEBOY)
# 3233  (PACK OF 72 RETROSPOT CAKE CASES, MINI PLAYING...
# 3236                   (SET 12 COLOUR PENCILS SPACEBOY)
# 3240  (MINI PLAYING CARDS DOLLY GIRL, SET OF 72 RETR...
# 3241                 (SET 12 COLOUR PENCILS DOLLY GIRL)
#
#                                             consequents  antecedent support  \
# 2587  (LARGE YELLOW BABUSHKA NOTEBOOK, SET OF 3 CAKE...            0.055556
# 2589  (LARGE RED BABUSHKA NOTEBOOK, SET OF 3 CAKE TI...            0.055556
# 2590                   (LARGE YELLOW BABUSHKA NOTEBOOK)            0.055556
# 2592                      (LARGE RED BABUSHKA NOTEBOOK)            0.055556
# 2593  (SET OF 3 CAKE TINS SKETCHBOOK, LARGE YELLOW B...            0.055556
# 2595  (LARGE RED BABUSHKA NOTEBOOK, SET OF 3 CAKE TI...            0.055556
# 2596                   (LARGE YELLOW BABUSHKA NOTEBOOK)            0.055556
# 2598                      (LARGE RED BABUSHKA NOTEBOOK)            0.055556
# 2599  (LARGE YELLOW BABUSHKA NOTEBOOK, VICTORIAN SEW...            0.055556
# 2601  (LARGE RED BABUSHKA NOTEBOOK, VICTORIAN SEWING...            0.055556
# 2610                      (LARGE RED BABUSHKA NOTEBOOK)            0.055556
# 2611  (PACK OF 12 TRADITIONAL CRAYONS, MAGIC DRAWING...            0.055556
# 2622                      (LARGE RED BABUSHKA NOTEBOOK)            0.055556
# 2623  (SET OF 3 CAKE TINS SKETCHBOOK, MAGIC DRAWING ...            0.055556
# 2634                      (LARGE RED BABUSHKA NOTEBOOK)            0.055556
# 2635  (PACK OF 12 TRADITIONAL CRAYONS, MAGIC DRAWING...            0.055556
# 2646                      (LARGE RED BABUSHKA NOTEBOOK)            0.055556
# 2647  (SET OF 3 CAKE TINS SKETCHBOOK, MAGIC DRAWING ...            0.055556
# 2658                      (LARGE RED BABUSHKA NOTEBOOK)            0.055556
# 2659  (PACK OF 12 TRADITIONAL CRAYONS, SET OF 3 CAKE...            0.055556
# 2670                      (LARGE RED BABUSHKA NOTEBOOK)            0.055556
# 2671  (PACK OF 12 TRADITIONAL CRAYONS, VICTORIAN SEW...            0.055556
# 2676                      (LARGE RED BABUSHKA NOTEBOOK)            0.055556
# 2677  (SET OF 3 CAKE TINS SKETCHBOOK, SET OF 3 CAKE ...            0.055556
# 2688                      (LARGE RED BABUSHKA NOTEBOOK)            0.055556
# 2689  (SET OF 3 CAKE TINS SKETCHBOOK, VICTORIAN SEWI...            0.055556
# 2700                   (LARGE YELLOW BABUSHKA NOTEBOOK)            0.055556
# 2701  (PACK OF 12 TRADITIONAL CRAYONS, MAGIC DRAWING...            0.055556
# 2712                   (LARGE YELLOW BABUSHKA NOTEBOOK)            0.055556
# 2713  (SET OF 3 CAKE TINS SKETCHBOOK, MAGIC DRAWING ...            0.055556
# 2724                   (LARGE YELLOW BABUSHKA NOTEBOOK)            0.055556
# 2725  (PACK OF 12 TRADITIONAL CRAYONS, MAGIC DRAWING...            0.055556
# 2736                   (LARGE YELLOW BABUSHKA NOTEBOOK)            0.055556
# 2737  (SET OF 3 CAKE TINS SKETCHBOOK, MAGIC DRAWING ...            0.055556
# 2748                   (LARGE YELLOW BABUSHKA NOTEBOOK)            0.055556
# 2749  (PACK OF 12 TRADITIONAL CRAYONS, SET OF 3 CAKE...            0.055556
# 2760                   (LARGE YELLOW BABUSHKA NOTEBOOK)            0.055556
# 2761  (PACK OF 12 TRADITIONAL CRAYONS, VICTORIAN SEW...            0.055556
# 2766                   (LARGE YELLOW BABUSHKA NOTEBOOK)            0.055556
# 2767  (SET OF 3 CAKE TINS SKETCHBOOK, SET OF 3 CAKE ...            0.055556
# 2778                   (LARGE YELLOW BABUSHKA NOTEBOOK)            0.055556
# 2779  (SET OF 3 CAKE TINS SKETCHBOOK, VICTORIAN SEWI...            0.055556
# 2788                 (LUNCH BOX WITH CUTLERY RETROSPOT)            0.055556
# 2793      (POSTAGE, ROUND SNACK BOXES SET OF4 WOODLAND)            0.055556
# 3227                   (SET 12 COLOUR PENCILS SPACEBOY)            0.055556
# 3230  (PACK OF 60 SPACEBOY CAKE CASES, MINI PLAYING ...            0.055556
# 3233                   (SET 12 COLOUR PENCILS SPACEBOY)            0.055556
# 3236  (PACK OF 72 RETROSPOT CAKE CASES, MINI PLAYING...            0.055556
# 3240                 (SET 12 COLOUR PENCILS DOLLY GIRL)            0.055556
# 3241  (MINI PLAYING CARDS DOLLY GIRL, SET OF 72 RETR...            0.055556
#
#       consequent support   support  confidence  lift  leverage  conviction
# 2587            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2589            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2590            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2592            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2593            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2595            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2596            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2598            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2599            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2601            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2610            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2611            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2622            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2623            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2634            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2635            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2646            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2647            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2658            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2659            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2670            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2671            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2676            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2677            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2688            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2689            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2700            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2701            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2712            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2713            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2724            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2725            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2736            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2737            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2748            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2749            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2760            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2761            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2766            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2767            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2778            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2779            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2788            0.055556  0.055556         1.0  18.0  0.052469         inf
# 2793            0.055556  0.055556         1.0  18.0  0.052469         inf
# 3227            0.055556  0.055556         1.0  18.0  0.052469         inf
# 3230            0.055556  0.055556         1.0  18.0  0.052469         inf
# 3233            0.055556  0.055556         1.0  18.0  0.052469         inf
# 3236            0.055556  0.055556         1.0  18.0  0.052469         inf
# 3240            0.055556  0.055556         1.0  18.0  0.052469         inf
# 3241            0.055556  0.055556         1.0  18.0  0.052469         inf

# %%
rules.iloc[200:250, 0:2]
# Out:
#                                             antecedents  \
# 2207  (SET OF 3 REGENCY CAKE TINS, TREASURE TIN BUFF...
# 2210                               (DOILEY STORAGE TIN)
# 2212  (TREASURE TIN GYMKHANA DESIGN, SET OF 3 REGENC...
# 2217                               (DOILEY STORAGE TIN)
# 2224  (GUMBALL COAT RACK, FAIRY CAKE FLANNEL ASSORTE...
# 2225         (GUMBALL COAT RACK, MOBILE VINTAGE HEARTS)
# 2228               (FAIRY CAKE FLANNEL ASSORTED COLOUR)
# 2229                            (MOBILE VINTAGE HEARTS)
# 2237                   (POSTAGE, MOBILE VINTAGE HEARTS)
# 2238      (FAIRY CAKE FLANNEL ASSORTED COLOUR, POSTAGE)
# 2239                            (MOBILE VINTAGE HEARTS)
# 2240               (FAIRY CAKE FLANNEL ASSORTED COLOUR)
# 2272                       (TOY TIDY SPACEBOY, POSTAGE)
# 2274            (POSTAGE, HOMEMADE JAM SCENTED CANDLES)
# 2275                                (TOY TIDY SPACEBOY)
# 2277                     (HOMEMADE JAM SCENTED CANDLES)
# 2398  (LARGE RED BABUSHKA NOTEBOOK, LARGE PURPLE BAB...
# 2399  (LARGE RED BABUSHKA NOTEBOOK, LARGE YELLOW BAB...
# 2400  (LARGE YELLOW BABUSHKA NOTEBOOK, LARGE PURPLE ...
# 2401                      (LARGE RED BABUSHKA NOTEBOOK)
# 2402                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2403                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2405  (LARGE RED BABUSHKA NOTEBOOK, MAGIC DRAWING SL...
# 2406  (LARGE PURPLE BABUSHKA NOTEBOOK, MAGIC DRAWING...
# 2407                      (LARGE RED BABUSHKA NOTEBOOK)
# 2408                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2411  (LARGE RED BABUSHKA NOTEBOOK, MAGIC DRAWING SL...
# 2412  (MAGIC DRAWING SLATE PURDEY, LARGE PURPLE BABU...
# 2413                      (LARGE RED BABUSHKA NOTEBOOK)
# 2414                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2416  (LARGE RED BABUSHKA NOTEBOOK, PACK OF 12 TRADI...
# 2418  (PACK OF 12 TRADITIONAL CRAYONS, LARGE PURPLE ...
# 2419                      (LARGE RED BABUSHKA NOTEBOOK)
# 2421                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2423  (LARGE RED BABUSHKA NOTEBOOK, SET OF 3 CAKE TI...
# 2424  (SET OF 3 CAKE TINS PANTRY DESIGN, LARGE PURPL...
# 2425                      (LARGE RED BABUSHKA NOTEBOOK)
# 2426                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2428  (LARGE RED BABUSHKA NOTEBOOK, SET OF 3 CAKE TI...
# 2430  (SET OF 3 CAKE TINS SKETCHBOOK, LARGE PURPLE B...
# 2431                      (LARGE RED BABUSHKA NOTEBOOK)
# 2433                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2434  (LARGE RED BABUSHKA NOTEBOOK, VICTORIAN SEWING...
# 2436  (VICTORIAN SEWING KIT, LARGE PURPLE BABUSHKA N...
# 2437                      (LARGE RED BABUSHKA NOTEBOOK)
# 2439                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2441  (LARGE YELLOW BABUSHKA NOTEBOOK, MAGIC DRAWING...
# 2442  (LARGE PURPLE BABUSHKA NOTEBOOK, MAGIC DRAWING...
# 2443                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2444                   (LARGE PURPLE BABUSHKA NOTEBOOK)
#
#                                             consequents
# 2207                               (DOILEY STORAGE TIN)
# 2210  (SET OF 3 REGENCY CAKE TINS, TREASURE TIN BUFF...
# 2212                               (DOILEY STORAGE TIN)
# 2217  (TREASURE TIN GYMKHANA DESIGN, SET OF 3 REGENC...
# 2224                            (MOBILE VINTAGE HEARTS)
# 2225               (FAIRY CAKE FLANNEL ASSORTED COLOUR)
# 2228         (GUMBALL COAT RACK, MOBILE VINTAGE HEARTS)
# 2229  (GUMBALL COAT RACK, FAIRY CAKE FLANNEL ASSORTE...
# 2237               (FAIRY CAKE FLANNEL ASSORTED COLOUR)
# 2238                            (MOBILE VINTAGE HEARTS)
# 2239      (FAIRY CAKE FLANNEL ASSORTED COLOUR, POSTAGE)
# 2240                   (POSTAGE, MOBILE VINTAGE HEARTS)
# 2272                     (HOMEMADE JAM SCENTED CANDLES)
# 2274                                (TOY TIDY SPACEBOY)
# 2275            (POSTAGE, HOMEMADE JAM SCENTED CANDLES)
# 2277                       (TOY TIDY SPACEBOY, POSTAGE)
# 2398                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2399                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2400                      (LARGE RED BABUSHKA NOTEBOOK)
# 2401  (LARGE YELLOW BABUSHKA NOTEBOOK, LARGE PURPLE ...
# 2402  (LARGE RED BABUSHKA NOTEBOOK, LARGE YELLOW BAB...
# 2403  (LARGE RED BABUSHKA NOTEBOOK, LARGE PURPLE BAB...
# 2405                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2406                      (LARGE RED BABUSHKA NOTEBOOK)
# 2407  (LARGE PURPLE BABUSHKA NOTEBOOK, MAGIC DRAWING...
# 2408  (LARGE RED BABUSHKA NOTEBOOK, MAGIC DRAWING SL...
# 2411                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2412                      (LARGE RED BABUSHKA NOTEBOOK)
# 2413  (MAGIC DRAWING SLATE PURDEY, LARGE PURPLE BABU...
# 2414  (LARGE RED BABUSHKA NOTEBOOK, MAGIC DRAWING SL...
# 2416                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2418                      (LARGE RED BABUSHKA NOTEBOOK)
# 2419  (PACK OF 12 TRADITIONAL CRAYONS, LARGE PURPLE ...
# 2421  (LARGE RED BABUSHKA NOTEBOOK, PACK OF 12 TRADI...
# 2423                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2424                      (LARGE RED BABUSHKA NOTEBOOK)
# 2425  (SET OF 3 CAKE TINS PANTRY DESIGN, LARGE PURPL...
# 2426  (LARGE RED BABUSHKA NOTEBOOK, SET OF 3 CAKE TI...
# 2428                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2430                      (LARGE RED BABUSHKA NOTEBOOK)
# 2431  (SET OF 3 CAKE TINS SKETCHBOOK, LARGE PURPLE B...
# 2433  (LARGE RED BABUSHKA NOTEBOOK, SET OF 3 CAKE TI...
# 2434                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2436                      (LARGE RED BABUSHKA NOTEBOOK)
# 2437  (VICTORIAN SEWING KIT, LARGE PURPLE BABUSHKA N...
# 2439  (LARGE RED BABUSHKA NOTEBOOK, VICTORIAN SEWING...
# 2441                   (LARGE PURPLE BABUSHKA NOTEBOOK)
# 2442                   (LARGE YELLOW BABUSHKA NOTEBOOK)
# 2443  (LARGE PURPLE BABUSHKA NOTEBOOK, MAGIC DRAWING...
# 2444  (LARGE YELLOW BABUSHKA NOTEBOOK, MAGIC DRAWING...

# %%
rules.iloc[2581,1]
# Out:
# frozenset({'LARGE PURPLE BABUSHKA NOTEBOOK', 'MAGIC DRAWING SLATE DOLLY GIRL'})

# %%
rules.iloc[2581,0]
# Out:
# frozenset({'SET OF 3 CAKE TINS PANTRY DESIGN',
#            'SET OF 3 CAKE TINS SKETCHBOOK'})
