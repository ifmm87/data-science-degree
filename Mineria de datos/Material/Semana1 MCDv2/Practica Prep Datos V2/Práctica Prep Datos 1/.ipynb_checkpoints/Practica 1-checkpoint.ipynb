# %%
# Libraries
#invite people for the Kaggle party
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn import preprocessing
from scipy import stats
from pandas import Series, DataFrame
from pandas.plotting import autocorrelation_plot
#from pandas.tools.plotting import scatter_matrix
from pylab import rcParams
from matplotlib import collections as collections
from matplotlib.patches import Rectangle
from itertools import cycle

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

rcParams['figure.figsize'] = 5,4
sb.set_style('whitegrid')
from numpy import median
from numpy import mean

# %%
df = pd.read_csv('credit-g1.csv')

# %%
df.head()
# Out:
#   checking_status  duration                    credit_history    purpose  \
# 0   'no checking'        24                   'existing paid'   radio/tv
# 1   'no checking'        48  'critical/other existing credit'  education
# 2   'no checking'        12                   'existing paid'   radio/tv
# 3   'no checking'        12  'critical/other existing credit'   radio/tv
# 4   'no checking'        24                   'existing paid'  'new car'
#
#    credit_amount savings_status employment  installment_commitment  \
# 0         3430.0    500<=X<1000        >=7                       3
# 1         6110.0           <100     1<=X<4                       1
# 2            NaN           <100     1<=X<4                       3
# 3            NaN           <100        >=7                       4
# 4            NaN     100<=X<500        >=7                       4
#
#   personal_status other_parties  ...   property_magnitude age  \
# 0   'male single'          none  ...                  car  31
# 1   'male single'          none  ...  'no known property'  31
# 2   'male single'          none  ...                  car  25
# 3   'male single'          none  ...        'real estate'  56
# 4  'male mar/wid'          none  ...        'real estate'  41
#
#    other_payment_plans     housing existing_credits                   job  \
# 0                 none         own                1               skilled
# 1                 bank  'for free'                1               skilled
# 2                 none         own                1               skilled
# 3                 none         own                1               skilled
# 4                 none        rent                1  'unskilled resident'
#
#   num_dependents  own_telephone foreign_worker class
# 0              2            yes            yes  good
# 1              1            yes            yes  good
# 2              1           none            yes  good
# 3              1           none            yes  good
# 4              1           none            yes  good
#
# [5 rows x 21 columns]

# %%
print('Cantidad de filas:', len(df))
# Out:
# Cantidad de filas: 51

# %%
# Pregunta 1
df.drop_duplicates(subset=None, inplace=True)
# esta funcion no retorna otro dataframe

# %%
print ('Cantidad de filas despues de eliminar duplicados', len(df))
# Out:
# Cantidad de filas despues de eliminar duplicados 50

# %%
# funcion para recuperar duplicados
def getDuplicateColumns(df):
    duplicateColumnNames = set()
    # Iterate over all the columns in dataframe
    for x in range(df.shape[1]):
        # Select column at xth index.
        col = df.iloc[:, x] # ubica el indice
        # Iterate over all the columns in DataFrame from (x+1)th index till end
        for y in range(x + 1, df.shape[1]):
            # Select column at yth index.
            otherCol = df.iloc[:, y]
            # Check if two columns at x 7 y index are equal
            if col.equals(otherCol):
                duplicateColumnNames.add(df.columns.values[y])
    return list(duplicateColumnNames)

# %%
# Get list of duplicate columns
columnasDuplicadas = getDuplicateColumns(df)
print('columnas duplicadas')
print('Las Columnas duplicadas son:')
for col in columnasDuplicadas:
    print('Columna : ', col)
# Out:
# columnas duplicadas
# Las Columnas duplicadas son:

# %%
#Pregunta 2
# Eliminar columnas  duplicadas
nuevoDf = df.drop(columns=getDuplicateColumns(df))
print("Dataframe Modificado", nuevoDf, sep='\n')
# Out:
# Dataframe Modificado
#    checking_status  duration                    credit_history  \
# 0    'no checking'        24                   'existing paid'
# 1    'no checking'        48  'critical/other existing credit'
# 2    'no checking'        12                   'existing paid'
# 3    'no checking'        12  'critical/other existing credit'
# 4    'no checking'        24                   'existing paid'
# 5               <0        12  'critical/other existing credit'
# 6    'no checking'        15                   'existing paid'
# 7         0<=X<200        11                   'existing paid'
# 8               <0        12                   'existing paid'
# 9    'no checking'        27              'delayed previously'
# 10              <0        30  'critical/other existing credit'
# 11   'no checking'        12                   'existing paid'
# 12              <0        48             'no credits/all paid'
# 13   'no checking'        12  'critical/other existing credit'
# 14              <0        12                   'existing paid'
# 15        0<=X<200        48                   'existing paid'
# 16   'no checking'        18  'critical/other existing credit'
# 17        0<=X<200         9                   'existing paid'
# 18              <0        12                   'existing paid'
# 19        0<=X<200        18  'critical/other existing credit'
# 20   'no checking'        18  'critical/other existing credit'
# 21   'no checking'        24  'critical/other existing credit'
# 22              <0        36                   'existing paid'
# 23              <0        36                   'existing paid'
# 24              <0         6                   'existing paid'
# 25   'no checking'        24                   'existing paid'
# 26              <0         6  'critical/other existing credit'
# 27   'no checking'         4  'critical/other existing credit'
# 28        0<=X<200        12                   'existing paid'
# 29              <0         9  'critical/other existing credit'
# 30   'no checking'         9                   'existing paid'
# 31   'no checking'        15                   'existing paid'
# 32              <0        48                   'existing paid'
# 33           >=200        10  'critical/other existing credit'
# 34        0<=X<200        24                   'existing paid'
# 35           >=200        24  'critical/other existing credit'
# 36        0<=X<200        20             'no credits/all paid'
# 37        0<=X<200        48                        'all paid'
# 38              <0        12                   'existing paid'
# 39   'no checking'         6  'critical/other existing credit'
# 40   'no checking'        24              'delayed previously'
# 41   'no checking'        12                   'existing paid'
# 42   'no checking'         4                   'existing paid'
# 43   'no checking'        12  'critical/other existing credit'
# 44   'no checking'        36  'critical/other existing credit'
# 45              <0        27  'critical/other existing credit'
# 46        0<=X<200        48             'no credits/all paid'
# 47        0<=X<200        60                   'existing paid'
# 48           >=200        30  'critical/other existing credit'
# 49        0<=X<200         6                   'existing paid'
#
#                 purpose  credit_amount      savings_status  employment  \
# 0              radio/tv         3430.0         500<=X<1000         >=7
# 1             education         6110.0                <100      1<=X<4
# 2              radio/tv            NaN                <100      1<=X<4
# 3              radio/tv            NaN                <100         >=7
# 4             'new car'            NaN          100<=X<500         >=7
# 5             'new car'            NaN                <100      1<=X<4
# 6   furniture/equipment            NaN                <100          <1
# 7   furniture/equipment            NaN              >=1000          <1
# 8             'new car'            NaN                <100      1<=X<4
# 9              business            NaN                <100      4<=X<7
# 10           'used car'            NaN                <100         >=7
# 11           'used car'            NaN              >=1000      4<=X<7
# 12           'used car'            NaN                <100         >=7
# 13  furniture/equipment            NaN         500<=X<1000      4<=X<7
# 14  furniture/equipment            NaN  'no known savings'         >=7
# 15                other            NaN  'no known savings'  unemployed
# 16            'new car'            NaN                <100      1<=X<4
# 17  furniture/equipment            NaN                <100      1<=X<4
# 18  furniture/equipment            NaN                <100  unemployed
# 19             business            NaN  'no known savings'      1<=X<4
# 20             radio/tv            NaN              >=1000      1<=X<4
# 21              repairs            NaN                <100      1<=X<4
# 22            'new car'            NaN                <100          <1
# 23  furniture/equipment            NaN                <100      1<=X<4
# 24            education            NaN                <100          <1
# 25            'new car'            NaN  'no known savings'          <1
# 26            'new car'            NaN                <100          <1
# 27             radio/tv            NaN                <100      4<=X<7
# 28             radio/tv         1534.0                <100          <1
# 29            'new car'         2799.0                <100      1<=X<4
# 30  furniture/equipment         1980.0                <100          <1
# 31            education         4623.0          100<=X<500      1<=X<4
# 32            education         7476.0                <100      4<=X<7
# 33             radio/tv         1347.0  'no known savings'      4<=X<7
# 34             radio/tv         2896.0          100<=X<500          <1
# 35             radio/tv         3148.0  'no known savings'      1<=X<4
# 36           'used car'         6148.0          100<=X<500         >=7
# 37             business         6416.0                <100         >=7
# 38             radio/tv         2214.0                <100      1<=X<4
# 39  furniture/equipment         1221.0  'no known savings'      1<=X<4
# 40            'new car'          717.0  'no known savings'         >=7
# 41             radio/tv          886.0  'no known savings'      1<=X<4
# 42  furniture/equipment          601.0                <100          <1
# 43  furniture/equipment         3331.0                <100         >=7
# 44            'new car'         6614.0                <100         >=7
# 45             business         2442.0                <100         >=7
# 46                other        18424.0                <100      1<=X<4
# 47            education         6288.0                <100      1<=X<4
# 48             radio/tv         3656.0  'no known savings'         >=7
# 49             radio/tv          753.0                <100      1<=X<4
#
#     installment_commitment       personal_status   other_parties  ...  \
# 0                        3         'male single'            none  ...
# 1                        1         'male single'            none  ...
# 2                        3         'male single'            none  ...
# 3                        4         'male single'            none  ...
# 4                        4        'male mar/wid'            none  ...
# 5                        3  'female div/dep/mar'  'co applicant'  ...
# 6                        2         'male single'            none  ...
# 7                        4  'female div/dep/mar'            none  ...
# 8                        4        'male mar/wid'            none  ...
# 9                        3         'male single'            none  ...
# 10                       3         'male single'            none  ...
# 11                       3         'male single'            none  ...
# 12                       3         'male single'            none  ...
# 13                       3  'female div/dep/mar'            none  ...
# 14                       2        'male div/sep'            none  ...
# 15                       3         'male single'            none  ...
# 16                       4  'female div/dep/mar'            none  ...
# 17                       1  'female div/dep/mar'            none  ...
# 18                       3  'female div/dep/mar'            none  ...
# 19                       4        'male mar/wid'            none  ...
# 20                       4         'male single'            none  ...
# 21                       4        'male div/sep'            none  ...
# 22                       4  'female div/dep/mar'            none  ...
# 23                       1         'male single'       guarantor  ...
# 24                       4  'female div/dep/mar'            none  ...
# 25                       4         'male single'            none  ...
# 26                       2         'male single'            none  ...
# 27                       2         'male single'            none  ...
# 28                       1        'male mar/wid'            none  ...
# 29                       2         'male single'            none  ...
# 30                       2  'female div/dep/mar'  'co applicant'  ...
# 31                       3         'male single'            none  ...
# 32                       4         'male single'            none  ...
# 33                       4         'male single'            none  ...
# 34                       2         'male single'            none  ...
# 35                       3         'male single'            none  ...
# 36                       3        'male mar/wid'            none  ...
# 37                       4  'female div/dep/mar'            none  ...
# 38                       4         'male single'            none  ...
# 39                       1        'male mar/wid'            none  ...
# 40                       4        'male mar/wid'            none  ...
# 41                       4  'female div/dep/mar'            none  ...
# 42                       1  'female div/dep/mar'            none  ...
# 43                       2         'male single'            none  ...
# 44                       4         'male single'            none  ...
# 45                       4         'male single'            none  ...
# 46                       1  'female div/dep/mar'            none  ...
# 47                       4         'male single'            none  ...
# 48                       4         'male single'            none  ...
# 49                       2  'female div/dep/mar'       guarantor  ...
#
#      property_magnitude age  other_payment_plans     housing existing_credits  \
# 0                   car  31                 none         own                1
# 1   'no known property'  31                 bank  'for free'                1
# 2                   car  25                 none         own                1
# 3         'real estate'  56                 none         own                1
# 4         'real estate'  41                 none        rent                1
# 5         'real estate'  29                 none         own                2
# 6      'life insurance'  27                 bank         own                2
# 7         'real estate'  20                 none         own                1
# 8         'real estate'  27                 none         own                1
# 9                   car  26                 none         own                2
# 10  'no known property'  38                 none  'for free'                3
# 11     'life insurance'  55                 none         own                1
# 12  'no known property'  24                 none  'for free'                2
# 13                  car  37                 none        rent                1
# 14     'life insurance'  49                 none         own                1
# 15  'no known property'  40                 bank  'for free'                1
# 16        'real estate'  36                 none         own                2
# 17                  car  29                 none         own                1
# 18  'no known property'  55                 none  'for free'                1
# 19        'real estate'  28                 bank         own                2
# 20        'real estate'  46                 none         own                2
# 21        'real estate'  33                 none         own                2
# 22                  car  34                 none         own                1
# 23     'life insurance'  37                 none         own                1
# 24     'life insurance'  23                 none         own                1
# 25     'life insurance'  54                 none         own                1
# 26        'real estate'  40                 none         own                1
# 27        'real estate'  42                 none         own                2
# 28        'real estate'  23                 none        rent                1
# 29        'real estate'  36                 none        rent                2
# 30                  car  19                 none        rent                2
# 31     'life insurance'  40                 none         own                1
# 32  'no known property'  50                 none  'for free'                1
# 33     'life insurance'  27                 none         own                2
# 34                  car  29                 none         own                1
# 35                  car  31                 none         own                2
# 36                  car  31                 bank         own                2
# 37  'no known property'  59                 none        rent                1
# 38     'life insurance'  24                 none         own                1
# 39     'life insurance'  27                 none         own                2
# 40                  car  54                 none         own                2
# 41                  car  21                 none         own                1
# 42        'real estate'  23                 none        rent                1
# 43     'life insurance'  42               stores         own                1
# 44                  car  34                 none         own                2
# 45                  car  43               stores         own                4
# 46     'life insurance'  32                 bank         own                1
# 47  'no known property'  42                 none  'for free'                1
# 48     'life insurance'  49               stores         own                2
# 49        'real estate'  64                 none         own                1
#
#                             job num_dependents  own_telephone foreign_worker  \
# 0                       skilled              2            yes            yes
# 1                       skilled              1            yes            yes
# 2                       skilled              1           none            yes
# 3                       skilled              1           none            yes
# 4          'unskilled resident'              1           none            yes
# 5                       skilled              1           none            yes
# 6          'unskilled resident'              1           none            yes
# 7                       skilled              1           none            yes
# 8          'unskilled resident'              1           none            yes
# 9                       skilled              1           none            yes
# 10  'high qualif/self emp/mgmt'              2            yes            yes
# 11                      skilled              1           none             no
# 12                      skilled              2           none            yes
# 13                      skilled              1            yes            yes
# 14         'unskilled resident'              1            yes            yes
# 15    'unemp/unskilled non res'              1            yes            yes
# 16                      skilled              1           none            yes
# 17                      skilled              1           none             no
# 18  'high qualif/self emp/mgmt'              1           none            yes
# 19                      skilled              1           none            yes
# 20                      skilled              1           none            yes
# 21                      skilled              1            yes            yes
# 22                      skilled              1            yes            yes
# 23                      skilled              2           none            yes
# 24                      skilled              1           none            yes
# 25                      skilled              1           none            yes
# 26         'unskilled resident'              2           none             no
# 27         'unskilled resident'              2           none            yes
# 28                      skilled              1           none            yes
# 29                      skilled              2           none            yes
# 30                      skilled              1           none            yes
# 31  'high qualif/self emp/mgmt'              1            yes            yes
# 32  'high qualif/self emp/mgmt'              1            yes            yes
# 33                      skilled              1            yes            yes
# 34                      skilled              1           none            yes
# 35                      skilled              1            yes            yes
# 36                      skilled              1            yes            yes
# 37                      skilled              1           none            yes
# 38         'unskilled resident'              1           none            yes
# 39                      skilled              1           none            yes
# 40                      skilled              1            yes            yes
# 41                      skilled              1           none            yes
# 42         'unskilled resident'              2           none            yes
# 43                      skilled              1           none            yes
# 44  'high qualif/self emp/mgmt'              1            yes            yes
# 45  'high qualif/self emp/mgmt'              2            yes            yes
# 46  'high qualif/self emp/mgmt'              1            yes             no
# 47                      skilled              1           none            yes
# 48         'unskilled resident'              1           none            yes
# 49                      skilled              1           none            yes
#
#    class
# 0   good
# 1   good
# 2   good
# 3   good
# 4   good
# 5    bad
# 6   good
# 7   good
# 8   good
# 9   good
# 10  good
# 11  good
# 12   bad
# 13  good
# 14  good
# 15  good
# 16  good
# 17   bad
# 18  good
# 19  good
# 20  good
# 21  good
# 22   bad
# 23  good
# 24   bad
# 25  good
# 26  good
# 27  good
# 28   bad
# 29  good
# 30   bad
# 31   bad
# 32  good
# 33  good
# 34  good
# 35  good
# 36  good
# 37   bad
# 38  good
# 39  good
# 40  good
# 41  good
# 42  good
# 43  good
# 44  good
# 45  good
# 46   bad
# 47   bad
# 48  good
# 49  good
#
# [50 rows x 21 columns]

# %%
# Pregunta 3
#Identificar columnas que tienen valores constantes
def drop_constant_columns(dataframe):
    result = dataframe.copy()
    for column in dataframe.columns:
        if len(dataframe[column].unique()) == 1:
            result = result.drop(column,axis=1)
    return result

# %%
# Eliminar columnas constante
df1 = drop_constant_columns(df)

# %%
print('El dataframe nuevo', df1.columns)
# Out:
# El dataframe nuevo Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
# pregunta 4
# data faltante

total = df.isnull().sum().sort_values(ascending=False)
porcentaje = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
dataFaltante = pd.concat([total, porcentaje], axis=1, keys=['Total', 'Percent'])
dataFaltante.head(20)
# Out:
#                         Total  Percent
# credit_amount              26     0.52
# class                       0     0.00
# other_parties               0     0.00
# duration                    0     0.00
# credit_history              0     0.00
# purpose                     0     0.00
# savings_status              0     0.00
# employment                  0     0.00
# installment_commitment      0     0.00
# personal_status             0     0.00
# residence_since             0     0.00
# foreign_worker              0     0.00
# property_magnitude          0     0.00
# age                         0     0.00
# other_payment_plans         0     0.00
# housing                     0     0.00
# existing_credits            0     0.00
# job                         0     0.00
# num_dependents              0     0.00
# own_telephone               0     0.00

# %%
df.isnull().sum()
# Out:
# checking_status            0
# duration                   0
# credit_history             0
# purpose                    0
# credit_amount             26
# savings_status             0
# employment                 0
# installment_commitment     0
# personal_status            0
# other_parties              0
# residence_since            0
# property_magnitude         0
# age                        0
# other_payment_plans        0
# housing                    0
# existing_credits           0
# job                        0
# num_dependents             0
# own_telephone              0
# foreign_worker             0
# class                      0
# dtype: int64

# %%
#Pregunta 5 Graficos
df.head()
#cars.index = cars.car_names
credit_amount = df['credit_amount']
prueba = credit_amount.plot(kind = 'hist')
print(prueba)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
plt.hist(credit_amount, bins=20)
plt.show()
#

# %%
quantiles = df['credit_amount'].quantile([0.25,0.5,0.75])
print(quantiles)
# para los quantiles se ordena
# el 25% de los creditos llega a 1487.
# el 50% llega a 3022.
# Out:
# 0.25    1487.25
# 0.50    3022.00
# 0.75    6119.50
# Name: credit_amount, dtype: float64

# %%
df.boxplot(column='credit_amount')
# Out:
# <AxesSubplot:>

# %%
df.head()
df.plot(kind='scatter', x='duration', y='credit_amount')
# la relacion entre las dos variables es directa/ascendente
# Out:
# <AxesSubplot:xlabel='duration', ylabel='credit_amount'>

# %%
from scipy.stats import gaussian_kde
density = gaussian_kde(df.age)
 
x_vals = np.linspace(0,100,200) # especificando limites
density.covariance_factor = lambda : .5 #constante de suavizamiento
 
density._compute_covariance()
plt.plot(x_vals,density(x_vals))
plt.show()

# %%
# Pregunta 6
# Aplicar expresión matemática para el cálculo (CreditAmount / Duración)*residence_since
df['nueva_columna'] = df['credit_amount']/df['duration']*df['residence_since']
df['nueva_columna']
df
# Out:
#    checking_status  duration                    credit_history  \
# 0    'no checking'        24                   'existing paid'
# 1    'no checking'        48  'critical/other existing credit'
# 2    'no checking'        12                   'existing paid'
# 3    'no checking'        12  'critical/other existing credit'
# 4    'no checking'        24                   'existing paid'
# 5               <0        12  'critical/other existing credit'
# 6    'no checking'        15                   'existing paid'
# 7         0<=X<200        11                   'existing paid'
# 8               <0        12                   'existing paid'
# 9    'no checking'        27              'delayed previously'
# 10              <0        30  'critical/other existing credit'
# 11   'no checking'        12                   'existing paid'
# 12              <0        48             'no credits/all paid'
# 13   'no checking'        12  'critical/other existing credit'
# 14              <0        12                   'existing paid'
# 15        0<=X<200        48                   'existing paid'
# 16   'no checking'        18  'critical/other existing credit'
# 17        0<=X<200         9                   'existing paid'
# 18              <0        12                   'existing paid'
# 19        0<=X<200        18  'critical/other existing credit'
# 20   'no checking'        18  'critical/other existing credit'
# 21   'no checking'        24  'critical/other existing credit'
# 22              <0        36                   'existing paid'
# 23              <0        36                   'existing paid'
# 24              <0         6                   'existing paid'
# 25   'no checking'        24                   'existing paid'
# 26              <0         6  'critical/other existing credit'
# 27   'no checking'         4  'critical/other existing credit'
# 28        0<=X<200        12                   'existing paid'
# 29              <0         9  'critical/other existing credit'
# 30   'no checking'         9                   'existing paid'
# 31   'no checking'        15                   'existing paid'
# 32              <0        48                   'existing paid'
# 33           >=200        10  'critical/other existing credit'
# 34        0<=X<200        24                   'existing paid'
# 35           >=200        24  'critical/other existing credit'
# 36        0<=X<200        20             'no credits/all paid'
# 37        0<=X<200        48                        'all paid'
# 38              <0        12                   'existing paid'
# 39   'no checking'         6  'critical/other existing credit'
# 40   'no checking'        24              'delayed previously'
# 41   'no checking'        12                   'existing paid'
# 42   'no checking'         4                   'existing paid'
# 43   'no checking'        12  'critical/other existing credit'
# 44   'no checking'        36  'critical/other existing credit'
# 45              <0        27  'critical/other existing credit'
# 46        0<=X<200        48             'no credits/all paid'
# 47        0<=X<200        60                   'existing paid'
# 48           >=200        30  'critical/other existing credit'
# 49        0<=X<200         6                   'existing paid'
# 50        0<=X<200         6                   'existing paid'
#
#                 purpose  credit_amount      savings_status  employment  \
# 0              radio/tv         3430.0         500<=X<1000         >=7
# 1             education         6110.0                <100      1<=X<4
# 2              radio/tv            NaN                <100      1<=X<4
# 3              radio/tv            NaN                <100         >=7
# 4             'new car'            NaN          100<=X<500         >=7
# 5             'new car'            NaN                <100      1<=X<4
# 6   furniture/equipment            NaN                <100          <1
# 7   furniture/equipment            NaN              >=1000          <1
# 8             'new car'            NaN                <100      1<=X<4
# 9              business            NaN                <100      4<=X<7
# 10           'used car'            NaN                <100         >=7
# 11           'used car'            NaN              >=1000      4<=X<7
# 12           'used car'            NaN                <100         >=7
# 13  furniture/equipment            NaN         500<=X<1000      4<=X<7
# 14  furniture/equipment            NaN  'no known savings'         >=7
# 15                other            NaN  'no known savings'  unemployed
# 16            'new car'            NaN                <100      1<=X<4
# 17  furniture/equipment            NaN                <100      1<=X<4
# 18  furniture/equipment            NaN                <100  unemployed
# 19             business            NaN  'no known savings'      1<=X<4
# 20             radio/tv            NaN              >=1000      1<=X<4
# 21              repairs            NaN                <100      1<=X<4
# 22            'new car'            NaN                <100          <1
# 23  furniture/equipment            NaN                <100      1<=X<4
# 24            education            NaN                <100          <1
# 25            'new car'            NaN  'no known savings'          <1
# 26            'new car'            NaN                <100          <1
# 27             radio/tv            NaN                <100      4<=X<7
# 28             radio/tv         1534.0                <100          <1
# 29            'new car'         2799.0                <100      1<=X<4
# 30  furniture/equipment         1980.0                <100          <1
# 31            education         4623.0          100<=X<500      1<=X<4
# 32            education         7476.0                <100      4<=X<7
# 33             radio/tv         1347.0  'no known savings'      4<=X<7
# 34             radio/tv         2896.0          100<=X<500          <1
# 35             radio/tv         3148.0  'no known savings'      1<=X<4
# 36           'used car'         6148.0          100<=X<500         >=7
# 37             business         6416.0                <100         >=7
# 38             radio/tv         2214.0                <100      1<=X<4
# 39  furniture/equipment         1221.0  'no known savings'      1<=X<4
# 40            'new car'          717.0  'no known savings'         >=7
# 41             radio/tv          886.0  'no known savings'      1<=X<4
# 42  furniture/equipment          601.0                <100          <1
# 43  furniture/equipment         3331.0                <100         >=7
# 44            'new car'         6614.0                <100         >=7
# 45             business         2442.0                <100         >=7
# 46                other        18424.0                <100      1<=X<4
# 47            education         6288.0                <100      1<=X<4
# 48             radio/tv         3656.0  'no known savings'         >=7
# 49             radio/tv          753.0                <100      1<=X<4
# 50             radio/tv          753.0                <100      1<=X<4
#
#     installment_commitment       personal_status   other_parties  ...  age  \
# 0                        3         'male single'            none  ...   31
# 1                        1         'male single'            none  ...   31
# 2                        3         'male single'            none  ...   25
# 3                        4         'male single'            none  ...   56
# 4                        4        'male mar/wid'            none  ...   41
# 5                        3  'female div/dep/mar'  'co applicant'  ...   29
# 6                        2         'male single'            none  ...   27
# 7                        4  'female div/dep/mar'            none  ...   20
# 8                        4        'male mar/wid'            none  ...   27
# 9                        3         'male single'            none  ...   26
# 10                       3         'male single'            none  ...   38
# 11                       3         'male single'            none  ...   55
# 12                       3         'male single'            none  ...   24
# 13                       3  'female div/dep/mar'            none  ...   37
# 14                       2        'male div/sep'            none  ...   49
# 15                       3         'male single'            none  ...   40
# 16                       4  'female div/dep/mar'            none  ...   36
# 17                       1  'female div/dep/mar'            none  ...   29
# 18                       3  'female div/dep/mar'            none  ...   55
# 19                       4        'male mar/wid'            none  ...   28
# 20                       4         'male single'            none  ...   46
# 21                       4        'male div/sep'            none  ...   33
# 22                       4  'female div/dep/mar'            none  ...   34
# 23                       1         'male single'       guarantor  ...   37
# 24                       4  'female div/dep/mar'            none  ...   23
# 25                       4         'male single'            none  ...   54
# 26                       2         'male single'            none  ...   40
# 27                       2         'male single'            none  ...   42
# 28                       1        'male mar/wid'            none  ...   23
# 29                       2         'male single'            none  ...   36
# 30                       2  'female div/dep/mar'  'co applicant'  ...   19
# 31                       3         'male single'            none  ...   40
# 32                       4         'male single'            none  ...   50
# 33                       4         'male single'            none  ...   27
# 34                       2         'male single'            none  ...   29
# 35                       3         'male single'            none  ...   31
# 36                       3        'male mar/wid'            none  ...   31
# 37                       4  'female div/dep/mar'            none  ...   59
# 38                       4         'male single'            none  ...   24
# 39                       1        'male mar/wid'            none  ...   27
# 40                       4        'male mar/wid'            none  ...   54
# 41                       4  'female div/dep/mar'            none  ...   21
# 42                       1  'female div/dep/mar'            none  ...   23
# 43                       2         'male single'            none  ...   42
# 44                       4         'male single'            none  ...   34
# 45                       4         'male single'            none  ...   43
# 46                       1  'female div/dep/mar'            none  ...   32
# 47                       4         'male single'            none  ...   42
# 48                       4         'male single'            none  ...   49
# 49                       2  'female div/dep/mar'       guarantor  ...   64
# 50                       2  'female div/dep/mar'       guarantor  ...   64
#
#    other_payment_plans     housing existing_credits  \
# 0                 none         own                1
# 1                 bank  'for free'                1
# 2                 none         own                1
# 3                 none         own                1
# 4                 none        rent                1
# 5                 none         own                2
# 6                 bank         own                2
# 7                 none         own                1
# 8                 none         own                1
# 9                 none         own                2
# 10                none  'for free'                3
# 11                none         own                1
# 12                none  'for free'                2
# 13                none        rent                1
# 14                none         own                1
# 15                bank  'for free'                1
# 16                none         own                2
# 17                none         own                1
# 18                none  'for free'                1
# 19                bank         own                2
# 20                none         own                2
# 21                none         own                2
# 22                none         own                1
# 23                none         own                1
# 24                none         own                1
# 25                none         own                1
# 26                none         own                1
# 27                none         own                2
# 28                none        rent                1
# 29                none        rent                2
# 30                none        rent                2
# 31                none         own                1
# 32                none  'for free'                1
# 33                none         own                2
# 34                none         own                1
# 35                none         own                2
# 36                bank         own                2
# 37                none        rent                1
# 38                none         own                1
# 39                none         own                2
# 40                none         own                2
# 41                none         own                1
# 42                none        rent                1
# 43              stores         own                1
# 44                none         own                2
# 45              stores         own                4
# 46                bank         own                1
# 47                none  'for free'                1
# 48              stores         own                2
# 49                none         own                1
# 50                none         own                1
#
#                             job  num_dependents own_telephone  foreign_worker  \
# 0                       skilled               2           yes             yes
# 1                       skilled               1           yes             yes
# 2                       skilled               1          none             yes
# 3                       skilled               1          none             yes
# 4          'unskilled resident'               1          none             yes
# 5                       skilled               1          none             yes
# 6          'unskilled resident'               1          none             yes
# 7                       skilled               1          none             yes
# 8          'unskilled resident'               1          none             yes
# 9                       skilled               1          none             yes
# 10  'high qualif/self emp/mgmt'               2           yes             yes
# 11                      skilled               1          none              no
# 12                      skilled               2          none             yes
# 13                      skilled               1           yes             yes
# 14         'unskilled resident'               1           yes             yes
# 15    'unemp/unskilled non res'               1           yes             yes
# 16                      skilled               1          none             yes
# 17                      skilled               1          none              no
# 18  'high qualif/self emp/mgmt'               1          none             yes
# 19                      skilled               1          none             yes
# 20                      skilled               1          none             yes
# 21                      skilled               1           yes             yes
# 22                      skilled               1           yes             yes
# 23                      skilled               2          none             yes
# 24                      skilled               1          none             yes
# 25                      skilled               1          none             yes
# 26         'unskilled resident'               2          none              no
# 27         'unskilled resident'               2          none             yes
# 28                      skilled               1          none             yes
# 29                      skilled               2          none             yes
# 30                      skilled               1          none             yes
# 31  'high qualif/self emp/mgmt'               1           yes             yes
# 32  'high qualif/self emp/mgmt'               1           yes             yes
# 33                      skilled               1           yes             yes
# 34                      skilled               1          none             yes
# 35                      skilled               1           yes             yes
# 36                      skilled               1           yes             yes
# 37                      skilled               1          none             yes
# 38         'unskilled resident'               1          none             yes
# 39                      skilled               1          none             yes
# 40                      skilled               1           yes             yes
# 41                      skilled               1          none             yes
# 42         'unskilled resident'               2          none             yes
# 43                      skilled               1          none             yes
# 44  'high qualif/self emp/mgmt'               1           yes             yes
# 45  'high qualif/self emp/mgmt'               2           yes             yes
# 46  'high qualif/self emp/mgmt'               1           yes              no
# 47                      skilled               1          none             yes
# 48         'unskilled resident'               1          none             yes
# 49                      skilled               1          none             yes
# 50                      skilled               1          none             yes
#
#    class nueva_columna
# 0   good    285.833333
# 1   good    381.875000
# 2   good           NaN
# 3   good           NaN
# 4   good           NaN
# 5    bad           NaN
# 6   good           NaN
# 7   good           NaN
# 8   good           NaN
# 9   good           NaN
# 10  good           NaN
# 11  good           NaN
# 12   bad           NaN
# 13  good           NaN
# 14  good           NaN
# 15  good           NaN
# 16  good           NaN
# 17   bad           NaN
# 18  good           NaN
# 19  good           NaN
# 20  good           NaN
# 21  good           NaN
# 22   bad           NaN
# 23  good           NaN
# 24   bad           NaN
# 25  good           NaN
# 26  good           NaN
# 27  good           NaN
# 28   bad    127.833333
# 29  good    622.000000
# 30   bad    440.000000
# 31   bad    616.400000
# 32  good    155.750000
# 33  good    269.400000
# 34  good    120.666667
# 35  good    262.333333
# 36  good   1229.600000
# 37   bad    401.000000
# 38  good    553.500000
# 39  good    407.000000
# 40  good    119.500000
# 41  good    147.666667
# 42  good    450.750000
# 43  good   1110.333333
# 44  good    734.888889
# 45  good    361.777778
# 46   bad    767.666667
# 47   bad    419.200000
# 48  good    487.466667
# 49  good    376.500000
# 50  good    376.500000
#
# [51 rows x 22 columns]

# %%
#Pregunta 7
#Obtenga una muestra para cada conjunto de Training, Testing y Validation

# select a random sample without replacement
from random import seed
array = seed(0,50) # Generate Data

print(array)
#df.iloc[1:25] 
##df.iloc[1:25,] 
#vector <- 1:50 
#indiceTraning <- sample(vector,25) 
#índice <- c(sample(vector,25), sample(vector,15),sample(vector,10)) 
#df1<- df[índice,]
# Out:
# None

# %%
#Pregunta 8
#discretizar duración, credit_amount, age, number_of_dependents.

fig, axs = plt.subplots(1,4) 
axs[0].hist(df.credit_amount)
axs[1].hist(df.duration)
axs[2].hist(df.age)
axs[3].hist(df.num_dependents)
df['credit_amount_discretizado'] = pd.cut(x=df['credit_amount'], bins=[1, 5000, 10000, 15000, 20000]) 
print(df['credit_amount_discretizado']) #
# Out:
# 0          (1.0, 5000.0]
# 1      (5000.0, 10000.0]
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28         (1.0, 5000.0]
# 29         (1.0, 5000.0]
# 30         (1.0, 5000.0]
# 31         (1.0, 5000.0]
# 32     (5000.0, 10000.0]
# 33         (1.0, 5000.0]
# 34         (1.0, 5000.0]
# 35         (1.0, 5000.0]
# 36     (5000.0, 10000.0]
# 37     (5000.0, 10000.0]
# 38         (1.0, 5000.0]
# 39         (1.0, 5000.0]
# 40         (1.0, 5000.0]
# 41         (1.0, 5000.0]
# 42         (1.0, 5000.0]
# 43         (1.0, 5000.0]
# 44     (5000.0, 10000.0]
# 45         (1.0, 5000.0]
# 46    (15000.0, 20000.0]
# 47     (5000.0, 10000.0]
# 48         (1.0, 5000.0]
# 49         (1.0, 5000.0]
# 50         (1.0, 5000.0]
# Name: credit_amount_discretizado, dtype: category
# Categories (4, interval[int64]): [(1, 5000] < (5000, 10000] < (10000, 15000] < (15000, 20000]]

# %%
#Pregunta 9
# Obtenga la matriz de correlación de las variables numéricas.
#
df_columnas_numericas = df.select_dtypes(include=[np.number])
corrmat = df_columnas_numericas.corr()
print(corrmat)
#correlation matrix
f, ax = plt.subplots(figsize=(12, 9))
sb.heatmap(corrmat, vmax=.8, square=True);
bottom, top = ax.get_ylim()
ax.set_ylim(bottom+0.5, top-0.5)
# Out:
#                         duration  credit_amount  installment_commitment  \
# duration                1.000000       0.709975                0.185119
# credit_amount           0.709975       1.000000               -0.067336
# installment_commitment  0.185119      -0.067336                1.000000
# residence_since         0.179999      -0.019677                0.266785
# age                     0.108825       0.019121                0.147038
# existing_credits        0.020722      -0.172344                0.182380
# num_dependents         -0.004259      -0.180615               -0.261998
# nueva_columna          -0.025070       0.377632               -0.119385
# foreign_mapeado         0.046602      -0.814008                0.323569
# own_telephone_mapeado   0.376682       0.403539                0.116190
#
#                         residence_since       age  existing_credits  \
# duration                       0.179999  0.108825          0.020722
# credit_amount                 -0.019677  0.019121         -0.172344
# installment_commitment         0.266785  0.147038          0.182380
# residence_since                1.000000  0.210421          0.177941
# age                            0.210421  1.000000         -0.110578
# existing_credits               0.177941 -0.110578          1.000000
# num_dependents                 0.011345 -0.074827          0.318744
# nueva_columna                  0.490758 -0.029480          0.055582
# foreign_mapeado                0.099199 -0.054078          0.206872
# own_telephone_mapeado          0.129969  0.032769          0.218010
#
#                         num_dependents  nueva_columna  foreign_mapeado  \
# duration                 -4.258999e-03      -0.025070         0.046602
# credit_amount            -1.806151e-01       0.377632        -0.814008
# installment_commitment   -2.619978e-01      -0.119385         0.323569
# residence_since           1.134461e-02       0.490758         0.099199
# age                      -7.482743e-02      -0.029480        -0.054078
# existing_credits          3.187442e-01       0.055582         0.206872
# num_dependents            1.000000e+00      -0.029823        -0.056269
# nueva_columna            -2.982307e-02       1.000000        -0.234827
# foreign_mapeado          -5.626864e-02      -0.234827         1.000000
# own_telephone_mapeado     4.845411e-17       0.071518         0.051571
#
#                         own_telephone_mapeado
# duration                         3.766816e-01
# credit_amount                    4.035391e-01
# installment_commitment           1.161895e-01
# residence_since                  1.299688e-01
# age                              3.276883e-02
# existing_credits                 2.180104e-01
# num_dependents                   4.845411e-17
# nueva_columna                    7.151826e-02
# foreign_mapeado                  5.157106e-02
# own_telephone_mapeado            1.000000e+00
# (10.5, -0.5)

# %%
#Pregunta 10
#Obtenga la tabla de relación de frecuencias entre los atributos job y purpose.

data_crosstab = pd.crosstab(df['job'], df['purpose'], margins = False) 
data_crosstab
# Out:
# purpose                      'new car'  'used car'  business  education  \
# job
# 'high qualif/self emp/mgmt'          1           1         1          2
# 'unemp/unskilled non res'            0           0         0          0
# 'unskilled resident'                 3           0         0          0
# skilled                              6           3         3          3
#
# purpose                      furniture/equipment  other  radio/tv  repairs
# job
# 'high qualif/self emp/mgmt'                    1      1         0        0
# 'unemp/unskilled non res'                      0      1         0        0
# 'unskilled resident'                           3      0         3        0
# skilled                                        7      0        11        1

# %%
#Pregunta 11
#Mapear a valores diferentes para atributos own_telephone, foreign_worker.

foreign_diccionario = {'yes': 1, 'no': 0}
own_telephone_diccionario = {'yes': 1, 'none': 0}
df['foreign_mapeado'] = df['foreign_worker'].map(foreign_diccionario)
df['own_telephone_mapeado'] = df['own_telephone'].map(own_telephone_diccionario)
df
#del tips['Gender']
# Out:
#    checking_status  duration                    credit_history  \
# 0    'no checking'        24                   'existing paid'
# 1    'no checking'        48  'critical/other existing credit'
# 2    'no checking'        12                   'existing paid'
# 3    'no checking'        12  'critical/other existing credit'
# 4    'no checking'        24                   'existing paid'
# 5               <0        12  'critical/other existing credit'
# 6    'no checking'        15                   'existing paid'
# 7         0<=X<200        11                   'existing paid'
# 8               <0        12                   'existing paid'
# 9    'no checking'        27              'delayed previously'
# 10              <0        30  'critical/other existing credit'
# 11   'no checking'        12                   'existing paid'
# 12              <0        48             'no credits/all paid'
# 13   'no checking'        12  'critical/other existing credit'
# 14              <0        12                   'existing paid'
# 15        0<=X<200        48                   'existing paid'
# 16   'no checking'        18  'critical/other existing credit'
# 17        0<=X<200         9                   'existing paid'
# 18              <0        12                   'existing paid'
# 19        0<=X<200        18  'critical/other existing credit'
# 20   'no checking'        18  'critical/other existing credit'
# 21   'no checking'        24  'critical/other existing credit'
# 22              <0        36                   'existing paid'
# 23              <0        36                   'existing paid'
# 24              <0         6                   'existing paid'
# 25   'no checking'        24                   'existing paid'
# 26              <0         6  'critical/other existing credit'
# 27   'no checking'         4  'critical/other existing credit'
# 28        0<=X<200        12                   'existing paid'
# 29              <0         9  'critical/other existing credit'
# 30   'no checking'         9                   'existing paid'
# 31   'no checking'        15                   'existing paid'
# 32              <0        48                   'existing paid'
# 33           >=200        10  'critical/other existing credit'
# 34        0<=X<200        24                   'existing paid'
# 35           >=200        24  'critical/other existing credit'
# 36        0<=X<200        20             'no credits/all paid'
# 37        0<=X<200        48                        'all paid'
# 38              <0        12                   'existing paid'
# 39   'no checking'         6  'critical/other existing credit'
# 40   'no checking'        24              'delayed previously'
# 41   'no checking'        12                   'existing paid'
# 42   'no checking'         4                   'existing paid'
# 43   'no checking'        12  'critical/other existing credit'
# 44   'no checking'        36  'critical/other existing credit'
# 45              <0        27  'critical/other existing credit'
# 46        0<=X<200        48             'no credits/all paid'
# 47        0<=X<200        60                   'existing paid'
# 48           >=200        30  'critical/other existing credit'
# 49        0<=X<200         6                   'existing paid'
# 50        0<=X<200         6                   'existing paid'
#
#                 purpose  credit_amount      savings_status  employment  \
# 0              radio/tv         3430.0         500<=X<1000         >=7
# 1             education         6110.0                <100      1<=X<4
# 2              radio/tv            NaN                <100      1<=X<4
# 3              radio/tv            NaN                <100         >=7
# 4             'new car'            NaN          100<=X<500         >=7
# 5             'new car'            NaN                <100      1<=X<4
# 6   furniture/equipment            NaN                <100          <1
# 7   furniture/equipment            NaN              >=1000          <1
# 8             'new car'            NaN                <100      1<=X<4
# 9              business            NaN                <100      4<=X<7
# 10           'used car'            NaN                <100         >=7
# 11           'used car'            NaN              >=1000      4<=X<7
# 12           'used car'            NaN                <100         >=7
# 13  furniture/equipment            NaN         500<=X<1000      4<=X<7
# 14  furniture/equipment            NaN  'no known savings'         >=7
# 15                other            NaN  'no known savings'  unemployed
# 16            'new car'            NaN                <100      1<=X<4
# 17  furniture/equipment            NaN                <100      1<=X<4
# 18  furniture/equipment            NaN                <100  unemployed
# 19             business            NaN  'no known savings'      1<=X<4
# 20             radio/tv            NaN              >=1000      1<=X<4
# 21              repairs            NaN                <100      1<=X<4
# 22            'new car'            NaN                <100          <1
# 23  furniture/equipment            NaN                <100      1<=X<4
# 24            education            NaN                <100          <1
# 25            'new car'            NaN  'no known savings'          <1
# 26            'new car'            NaN                <100          <1
# 27             radio/tv            NaN                <100      4<=X<7
# 28             radio/tv         1534.0                <100          <1
# 29            'new car'         2799.0                <100      1<=X<4
# 30  furniture/equipment         1980.0                <100          <1
# 31            education         4623.0          100<=X<500      1<=X<4
# 32            education         7476.0                <100      4<=X<7
# 33             radio/tv         1347.0  'no known savings'      4<=X<7
# 34             radio/tv         2896.0          100<=X<500          <1
# 35             radio/tv         3148.0  'no known savings'      1<=X<4
# 36           'used car'         6148.0          100<=X<500         >=7
# 37             business         6416.0                <100         >=7
# 38             radio/tv         2214.0                <100      1<=X<4
# 39  furniture/equipment         1221.0  'no known savings'      1<=X<4
# 40            'new car'          717.0  'no known savings'         >=7
# 41             radio/tv          886.0  'no known savings'      1<=X<4
# 42  furniture/equipment          601.0                <100          <1
# 43  furniture/equipment         3331.0                <100         >=7
# 44            'new car'         6614.0                <100         >=7
# 45             business         2442.0                <100         >=7
# 46                other        18424.0                <100      1<=X<4
# 47            education         6288.0                <100      1<=X<4
# 48             radio/tv         3656.0  'no known savings'         >=7
# 49             radio/tv          753.0                <100      1<=X<4
# 50             radio/tv          753.0                <100      1<=X<4
#
#     installment_commitment       personal_status   other_parties  ...  \
# 0                        3         'male single'            none  ...
# 1                        1         'male single'            none  ...
# 2                        3         'male single'            none  ...
# 3                        4         'male single'            none  ...
# 4                        4        'male mar/wid'            none  ...
# 5                        3  'female div/dep/mar'  'co applicant'  ...
# 6                        2         'male single'            none  ...
# 7                        4  'female div/dep/mar'            none  ...
# 8                        4        'male mar/wid'            none  ...
# 9                        3         'male single'            none  ...
# 10                       3         'male single'            none  ...
# 11                       3         'male single'            none  ...
# 12                       3         'male single'            none  ...
# 13                       3  'female div/dep/mar'            none  ...
# 14                       2        'male div/sep'            none  ...
# 15                       3         'male single'            none  ...
# 16                       4  'female div/dep/mar'            none  ...
# 17                       1  'female div/dep/mar'            none  ...
# 18                       3  'female div/dep/mar'            none  ...
# 19                       4        'male mar/wid'            none  ...
# 20                       4         'male single'            none  ...
# 21                       4        'male div/sep'            none  ...
# 22                       4  'female div/dep/mar'            none  ...
# 23                       1         'male single'       guarantor  ...
# 24                       4  'female div/dep/mar'            none  ...
# 25                       4         'male single'            none  ...
# 26                       2         'male single'            none  ...
# 27                       2         'male single'            none  ...
# 28                       1        'male mar/wid'            none  ...
# 29                       2         'male single'            none  ...
# 30                       2  'female div/dep/mar'  'co applicant'  ...
# 31                       3         'male single'            none  ...
# 32                       4         'male single'            none  ...
# 33                       4         'male single'            none  ...
# 34                       2         'male single'            none  ...
# 35                       3         'male single'            none  ...
# 36                       3        'male mar/wid'            none  ...
# 37                       4  'female div/dep/mar'            none  ...
# 38                       4         'male single'            none  ...
# 39                       1        'male mar/wid'            none  ...
# 40                       4        'male mar/wid'            none  ...
# 41                       4  'female div/dep/mar'            none  ...
# 42                       1  'female div/dep/mar'            none  ...
# 43                       2         'male single'            none  ...
# 44                       4         'male single'            none  ...
# 45                       4         'male single'            none  ...
# 46                       1  'female div/dep/mar'            none  ...
# 47                       4         'male single'            none  ...
# 48                       4         'male single'            none  ...
# 49                       2  'female div/dep/mar'       guarantor  ...
# 50                       2  'female div/dep/mar'       guarantor  ...
#
#                             job num_dependents  own_telephone foreign_worker  \
# 0                       skilled              2            yes            yes
# 1                       skilled              1            yes            yes
# 2                       skilled              1           none            yes
# 3                       skilled              1           none            yes
# 4          'unskilled resident'              1           none            yes
# 5                       skilled              1           none            yes
# 6          'unskilled resident'              1           none            yes
# 7                       skilled              1           none            yes
# 8          'unskilled resident'              1           none            yes
# 9                       skilled              1           none            yes
# 10  'high qualif/self emp/mgmt'              2            yes            yes
# 11                      skilled              1           none             no
# 12                      skilled              2           none            yes
# 13                      skilled              1            yes            yes
# 14         'unskilled resident'              1            yes            yes
# 15    'unemp/unskilled non res'              1            yes            yes
# 16                      skilled              1           none            yes
# 17                      skilled              1           none             no
# 18  'high qualif/self emp/mgmt'              1           none            yes
# 19                      skilled              1           none            yes
# 20                      skilled              1           none            yes
# 21                      skilled              1            yes            yes
# 22                      skilled              1            yes            yes
# 23                      skilled              2           none            yes
# 24                      skilled              1           none            yes
# 25                      skilled              1           none            yes
# 26         'unskilled resident'              2           none             no
# 27         'unskilled resident'              2           none            yes
# 28                      skilled              1           none            yes
# 29                      skilled              2           none            yes
# 30                      skilled              1           none            yes
# 31  'high qualif/self emp/mgmt'              1            yes            yes
# 32  'high qualif/self emp/mgmt'              1            yes            yes
# 33                      skilled              1            yes            yes
# 34                      skilled              1           none            yes
# 35                      skilled              1            yes            yes
# 36                      skilled              1            yes            yes
# 37                      skilled              1           none            yes
# 38         'unskilled resident'              1           none            yes
# 39                      skilled              1           none            yes
# 40                      skilled              1            yes            yes
# 41                      skilled              1           none            yes
# 42         'unskilled resident'              2           none            yes
# 43                      skilled              1           none            yes
# 44  'high qualif/self emp/mgmt'              1            yes            yes
# 45  'high qualif/self emp/mgmt'              2            yes            yes
# 46  'high qualif/self emp/mgmt'              1            yes             no
# 47                      skilled              1           none            yes
# 48         'unskilled resident'              1           none            yes
# 49                      skilled              1           none            yes
# 50                      skilled              1           none            yes
#
#    class  nueva_columna                bins  foreign_mapeado  \
# 0   good     285.833333       (1.0, 5000.0]                1
# 1   good     381.875000   (5000.0, 10000.0]                1
# 2   good            NaN                 NaN                1
# 3   good            NaN                 NaN                1
# 4   good            NaN                 NaN                1
# 5    bad            NaN                 NaN                1
# 6   good            NaN                 NaN                1
# 7   good            NaN                 NaN                1
# 8   good            NaN                 NaN                1
# 9   good            NaN                 NaN                1
# 10  good            NaN                 NaN                1
# 11  good            NaN                 NaN                0
# 12   bad            NaN                 NaN                1
# 13  good            NaN                 NaN                1
# 14  good            NaN                 NaN                1
# 15  good            NaN                 NaN                1
# 16  good            NaN                 NaN                1
# 17   bad            NaN                 NaN                0
# 18  good            NaN                 NaN                1
# 19  good            NaN                 NaN                1
# 20  good            NaN                 NaN                1
# 21  good            NaN                 NaN                1
# 22   bad            NaN                 NaN                1
# 23  good            NaN                 NaN                1
# 24   bad            NaN                 NaN                1
# 25  good            NaN                 NaN                1
# 26  good            NaN                 NaN                0
# 27  good            NaN                 NaN                1
# 28   bad     127.833333       (1.0, 5000.0]                1
# 29  good     622.000000       (1.0, 5000.0]                1
# 30   bad     440.000000       (1.0, 5000.0]                1
# 31   bad     616.400000       (1.0, 5000.0]                1
# 32  good     155.750000   (5000.0, 10000.0]                1
# 33  good     269.400000       (1.0, 5000.0]                1
# 34  good     120.666667       (1.0, 5000.0]                1
# 35  good     262.333333       (1.0, 5000.0]                1
# 36  good    1229.600000   (5000.0, 10000.0]                1
# 37   bad     401.000000   (5000.0, 10000.0]                1
# 38  good     553.500000       (1.0, 5000.0]                1
# 39  good     407.000000       (1.0, 5000.0]                1
# 40  good     119.500000       (1.0, 5000.0]                1
# 41  good     147.666667       (1.0, 5000.0]                1
# 42  good     450.750000       (1.0, 5000.0]                1
# 43  good    1110.333333       (1.0, 5000.0]                1
# 44  good     734.888889   (5000.0, 10000.0]                1
# 45  good     361.777778       (1.0, 5000.0]                1
# 46   bad     767.666667  (15000.0, 20000.0]                0
# 47   bad     419.200000   (5000.0, 10000.0]                1
# 48  good     487.466667       (1.0, 5000.0]                1
# 49  good     376.500000       (1.0, 5000.0]                1
# 50  good     376.500000       (1.0, 5000.0]                1
#
#    own_telephone_mapeado credit_amount_discretizado
# 0                      1              (1.0, 5000.0]
# 1                      1          (5000.0, 10000.0]
# 2                      0                        NaN
# 3                      0                        NaN
# 4                      0                        NaN
# 5                      0                        NaN
# 6                      0                        NaN
# 7                      0                        NaN
# 8                      0                        NaN
# 9                      0                        NaN
# 10                     1                        NaN
# 11                     0                        NaN
# 12                     0                        NaN
# 13                     1                        NaN
# 14                     1                        NaN
# 15                     1                        NaN
# 16                     0                        NaN
# 17                     0                        NaN
# 18                     0                        NaN
# 19                     0                        NaN
# 20                     0                        NaN
# 21                     1                        NaN
# 22                     1                        NaN
# 23                     0                        NaN
# 24                     0                        NaN
# 25                     0                        NaN
# 26                     0                        NaN
# 27                     0                        NaN
# 28                     0              (1.0, 5000.0]
# 29                     0              (1.0, 5000.0]
# 30                     0              (1.0, 5000.0]
# 31                     1              (1.0, 5000.0]
# 32                     1          (5000.0, 10000.0]
# 33                     1              (1.0, 5000.0]
# 34                     0              (1.0, 5000.0]
# 35                     1              (1.0, 5000.0]
# 36                     1          (5000.0, 10000.0]
# 37                     0          (5000.0, 10000.0]
# 38                     0              (1.0, 5000.0]
# 39                     0              (1.0, 5000.0]
# 40                     1              (1.0, 5000.0]
# 41                     0              (1.0, 5000.0]
# 42                     0              (1.0, 5000.0]
# 43                     0              (1.0, 5000.0]
# 44                     1          (5000.0, 10000.0]
# 45                     1              (1.0, 5000.0]
# 46                     1         (15000.0, 20000.0]
# 47                     0          (5000.0, 10000.0]
# 48                     0              (1.0, 5000.0]
# 49                     0              (1.0, 5000.0]
# 50                     0              (1.0, 5000.0]
#
# [51 rows x 26 columns]

# %%
#Pregunta 12
# Normalizar el campo instalment_commitment por frecuencia.
names = ['installment_commitment'] # or names = df.columns
# Normalize total_bedrooms column
#x_array = np.array(titanic['Fare'])
x_array = np.array(df['installment_commitment'])
normalized_X = preprocessing.normalize([x_array])
normalized_df = pd.DataFrame(normalized_X.flatten(), columns=names)
normalized_X
normalized_df
# Out:
#     installment_commitment
# 0                 0.134164
# 1                 0.044721
# 2                 0.134164
# 3                 0.178885
# 4                 0.178885
# 5                 0.134164
# 6                 0.089443
# 7                 0.178885
# 8                 0.178885
# 9                 0.134164
# 10                0.134164
# 11                0.134164
# 12                0.134164
# 13                0.134164
# 14                0.089443
# 15                0.134164
# 16                0.178885
# 17                0.044721
# 18                0.134164
# 19                0.178885
# 20                0.178885
# 21                0.178885
# 22                0.178885
# 23                0.044721
# 24                0.178885
# 25                0.178885
# 26                0.089443
# 27                0.089443
# 28                0.044721
# 29                0.089443
# 30                0.089443
# 31                0.134164
# 32                0.178885
# 33                0.178885
# 34                0.089443
# 35                0.134164
# 36                0.134164
# 37                0.178885
# 38                0.178885
# 39                0.044721
# 40                0.178885
# 41                0.178885
# 42                0.044721
# 43                0.089443
# 44                0.178885
# 45                0.178885
# 46                0.044721
# 47                0.178885
# 48                0.178885
# 49                0.089443
# 50                0.089443

# %%
#Pregunta 13
#Normalizar el campo instalment_commitment en el rango (-1,2)
minimo = df['installment_commitment'].min()
maximo = df['installment_commitment'].max()
minimo,maximo
df['installment_commitment_normalized']= 2-(-1)*((df['installment_commitment'] - minimo)/(maximo - minimo)) + (-1)
df
# Out:
#    checking_status  duration                    credit_history  \
# 0    'no checking'        24                   'existing paid'
# 1    'no checking'        48  'critical/other existing credit'
# 2    'no checking'        12                   'existing paid'
# 3    'no checking'        12  'critical/other existing credit'
# 4    'no checking'        24                   'existing paid'
# 5               <0        12  'critical/other existing credit'
# 6    'no checking'        15                   'existing paid'
# 7         0<=X<200        11                   'existing paid'
# 8               <0        12                   'existing paid'
# 9    'no checking'        27              'delayed previously'
# 10              <0        30  'critical/other existing credit'
# 11   'no checking'        12                   'existing paid'
# 12              <0        48             'no credits/all paid'
# 13   'no checking'        12  'critical/other existing credit'
# 14              <0        12                   'existing paid'
# 15        0<=X<200        48                   'existing paid'
# 16   'no checking'        18  'critical/other existing credit'
# 17        0<=X<200         9                   'existing paid'
# 18              <0        12                   'existing paid'
# 19        0<=X<200        18  'critical/other existing credit'
# 20   'no checking'        18  'critical/other existing credit'
# 21   'no checking'        24  'critical/other existing credit'
# 22              <0        36                   'existing paid'
# 23              <0        36                   'existing paid'
# 24              <0         6                   'existing paid'
# 25   'no checking'        24                   'existing paid'
# 26              <0         6  'critical/other existing credit'
# 27   'no checking'         4  'critical/other existing credit'
# 28        0<=X<200        12                   'existing paid'
# 29              <0         9  'critical/other existing credit'
# 30   'no checking'         9                   'existing paid'
# 31   'no checking'        15                   'existing paid'
# 32              <0        48                   'existing paid'
# 33           >=200        10  'critical/other existing credit'
# 34        0<=X<200        24                   'existing paid'
# 35           >=200        24  'critical/other existing credit'
# 36        0<=X<200        20             'no credits/all paid'
# 37        0<=X<200        48                        'all paid'
# 38              <0        12                   'existing paid'
# 39   'no checking'         6  'critical/other existing credit'
# 40   'no checking'        24              'delayed previously'
# 41   'no checking'        12                   'existing paid'
# 42   'no checking'         4                   'existing paid'
# 43   'no checking'        12  'critical/other existing credit'
# 44   'no checking'        36  'critical/other existing credit'
# 45              <0        27  'critical/other existing credit'
# 46        0<=X<200        48             'no credits/all paid'
# 47        0<=X<200        60                   'existing paid'
# 48           >=200        30  'critical/other existing credit'
# 49        0<=X<200         6                   'existing paid'
# 50        0<=X<200         6                   'existing paid'
#
#                 purpose  credit_amount      savings_status  employment  \
# 0              radio/tv         3430.0         500<=X<1000         >=7
# 1             education         6110.0                <100      1<=X<4
# 2              radio/tv            NaN                <100      1<=X<4
# 3              radio/tv            NaN                <100         >=7
# 4             'new car'            NaN          100<=X<500         >=7
# 5             'new car'            NaN                <100      1<=X<4
# 6   furniture/equipment            NaN                <100          <1
# 7   furniture/equipment            NaN              >=1000          <1
# 8             'new car'            NaN                <100      1<=X<4
# 9              business            NaN                <100      4<=X<7
# 10           'used car'            NaN                <100         >=7
# 11           'used car'            NaN              >=1000      4<=X<7
# 12           'used car'            NaN                <100         >=7
# 13  furniture/equipment            NaN         500<=X<1000      4<=X<7
# 14  furniture/equipment            NaN  'no known savings'         >=7
# 15                other            NaN  'no known savings'  unemployed
# 16            'new car'            NaN                <100      1<=X<4
# 17  furniture/equipment            NaN                <100      1<=X<4
# 18  furniture/equipment            NaN                <100  unemployed
# 19             business            NaN  'no known savings'      1<=X<4
# 20             radio/tv            NaN              >=1000      1<=X<4
# 21              repairs            NaN                <100      1<=X<4
# 22            'new car'            NaN                <100          <1
# 23  furniture/equipment            NaN                <100      1<=X<4
# 24            education            NaN                <100          <1
# 25            'new car'            NaN  'no known savings'          <1
# 26            'new car'            NaN                <100          <1
# 27             radio/tv            NaN                <100      4<=X<7
# 28             radio/tv         1534.0                <100          <1
# 29            'new car'         2799.0                <100      1<=X<4
# 30  furniture/equipment         1980.0                <100          <1
# 31            education         4623.0          100<=X<500      1<=X<4
# 32            education         7476.0                <100      4<=X<7
# 33             radio/tv         1347.0  'no known savings'      4<=X<7
# 34             radio/tv         2896.0          100<=X<500          <1
# 35             radio/tv         3148.0  'no known savings'      1<=X<4
# 36           'used car'         6148.0          100<=X<500         >=7
# 37             business         6416.0                <100         >=7
# 38             radio/tv         2214.0                <100      1<=X<4
# 39  furniture/equipment         1221.0  'no known savings'      1<=X<4
# 40            'new car'          717.0  'no known savings'         >=7
# 41             radio/tv          886.0  'no known savings'      1<=X<4
# 42  furniture/equipment          601.0                <100          <1
# 43  furniture/equipment         3331.0                <100         >=7
# 44            'new car'         6614.0                <100         >=7
# 45             business         2442.0                <100         >=7
# 46                other        18424.0                <100      1<=X<4
# 47            education         6288.0                <100      1<=X<4
# 48             radio/tv         3656.0  'no known savings'         >=7
# 49             radio/tv          753.0                <100      1<=X<4
# 50             radio/tv          753.0                <100      1<=X<4
#
#     installment_commitment       personal_status   other_parties  ...  \
# 0                        3         'male single'            none  ...
# 1                        1         'male single'            none  ...
# 2                        3         'male single'            none  ...
# 3                        4         'male single'            none  ...
# 4                        4        'male mar/wid'            none  ...
# 5                        3  'female div/dep/mar'  'co applicant'  ...
# 6                        2         'male single'            none  ...
# 7                        4  'female div/dep/mar'            none  ...
# 8                        4        'male mar/wid'            none  ...
# 9                        3         'male single'            none  ...
# 10                       3         'male single'            none  ...
# 11                       3         'male single'            none  ...
# 12                       3         'male single'            none  ...
# 13                       3  'female div/dep/mar'            none  ...
# 14                       2        'male div/sep'            none  ...
# 15                       3         'male single'            none  ...
# 16                       4  'female div/dep/mar'            none  ...
# 17                       1  'female div/dep/mar'            none  ...
# 18                       3  'female div/dep/mar'            none  ...
# 19                       4        'male mar/wid'            none  ...
# 20                       4         'male single'            none  ...
# 21                       4        'male div/sep'            none  ...
# 22                       4  'female div/dep/mar'            none  ...
# 23                       1         'male single'       guarantor  ...
# 24                       4  'female div/dep/mar'            none  ...
# 25                       4         'male single'            none  ...
# 26                       2         'male single'            none  ...
# 27                       2         'male single'            none  ...
# 28                       1        'male mar/wid'            none  ...
# 29                       2         'male single'            none  ...
# 30                       2  'female div/dep/mar'  'co applicant'  ...
# 31                       3         'male single'            none  ...
# 32                       4         'male single'            none  ...
# 33                       4         'male single'            none  ...
# 34                       2         'male single'            none  ...
# 35                       3         'male single'            none  ...
# 36                       3        'male mar/wid'            none  ...
# 37                       4  'female div/dep/mar'            none  ...
# 38                       4         'male single'            none  ...
# 39                       1        'male mar/wid'            none  ...
# 40                       4        'male mar/wid'            none  ...
# 41                       4  'female div/dep/mar'            none  ...
# 42                       1  'female div/dep/mar'            none  ...
# 43                       2         'male single'            none  ...
# 44                       4         'male single'            none  ...
# 45                       4         'male single'            none  ...
# 46                       1  'female div/dep/mar'            none  ...
# 47                       4         'male single'            none  ...
# 48                       4         'male single'            none  ...
# 49                       2  'female div/dep/mar'       guarantor  ...
# 50                       2  'female div/dep/mar'       guarantor  ...
#
#     num_dependents own_telephone  foreign_worker class nueva_columna  \
# 0                2           yes             yes  good    285.833333
# 1                1           yes             yes  good    381.875000
# 2                1          none             yes  good           NaN
# 3                1          none             yes  good           NaN
# 4                1          none             yes  good           NaN
# 5                1          none             yes   bad           NaN
# 6                1          none             yes  good           NaN
# 7                1          none             yes  good           NaN
# 8                1          none             yes  good           NaN
# 9                1          none             yes  good           NaN
# 10               2           yes             yes  good           NaN
# 11               1          none              no  good           NaN
# 12               2          none             yes   bad           NaN
# 13               1           yes             yes  good           NaN
# 14               1           yes             yes  good           NaN
# 15               1           yes             yes  good           NaN
# 16               1          none             yes  good           NaN
# 17               1          none              no   bad           NaN
# 18               1          none             yes  good           NaN
# 19               1          none             yes  good           NaN
# 20               1          none             yes  good           NaN
# 21               1           yes             yes  good           NaN
# 22               1           yes             yes   bad           NaN
# 23               2          none             yes  good           NaN
# 24               1          none             yes   bad           NaN
# 25               1          none             yes  good           NaN
# 26               2          none              no  good           NaN
# 27               2          none             yes  good           NaN
# 28               1          none             yes   bad    127.833333
# 29               2          none             yes  good    622.000000
# 30               1          none             yes   bad    440.000000
# 31               1           yes             yes   bad    616.400000
# 32               1           yes             yes  good    155.750000
# 33               1           yes             yes  good    269.400000
# 34               1          none             yes  good    120.666667
# 35               1           yes             yes  good    262.333333
# 36               1           yes             yes  good   1229.600000
# 37               1          none             yes   bad    401.000000
# 38               1          none             yes  good    553.500000
# 39               1          none             yes  good    407.000000
# 40               1           yes             yes  good    119.500000
# 41               1          none             yes  good    147.666667
# 42               2          none             yes  good    450.750000
# 43               1          none             yes  good   1110.333333
# 44               1           yes             yes  good    734.888889
# 45               2           yes             yes  good    361.777778
# 46               1           yes              no   bad    767.666667
# 47               1          none             yes   bad    419.200000
# 48               1          none             yes  good    487.466667
# 49               1          none             yes  good    376.500000
# 50               1          none             yes  good    376.500000
#
#                   bins foreign_mapeado  own_telephone_mapeado  \
# 0        (1.0, 5000.0]               1                      1
# 1    (5000.0, 10000.0]               1                      1
# 2                  NaN               1                      0
# 3                  NaN               1                      0
# 4                  NaN               1                      0
# 5                  NaN               1                      0
# 6                  NaN               1                      0
# 7                  NaN               1                      0
# 8                  NaN               1                      0
# 9                  NaN               1                      0
# 10                 NaN               1                      1
# 11                 NaN               0                      0
# 12                 NaN               1                      0
# 13                 NaN               1                      1
# 14                 NaN               1                      1
# 15                 NaN               1                      1
# 16                 NaN               1                      0
# 17                 NaN               0                      0
# 18                 NaN               1                      0
# 19                 NaN               1                      0
# 20                 NaN               1                      0
# 21                 NaN               1                      1
# 22                 NaN               1                      1
# 23                 NaN               1                      0
# 24                 NaN               1                      0
# 25                 NaN               1                      0
# 26                 NaN               0                      0
# 27                 NaN               1                      0
# 28       (1.0, 5000.0]               1                      0
# 29       (1.0, 5000.0]               1                      0
# 30       (1.0, 5000.0]               1                      0
# 31       (1.0, 5000.0]               1                      1
# 32   (5000.0, 10000.0]               1                      1
# 33       (1.0, 5000.0]               1                      1
# 34       (1.0, 5000.0]               1                      0
# 35       (1.0, 5000.0]               1                      1
# 36   (5000.0, 10000.0]               1                      1
# 37   (5000.0, 10000.0]               1                      0
# 38       (1.0, 5000.0]               1                      0
# 39       (1.0, 5000.0]               1                      0
# 40       (1.0, 5000.0]               1                      1
# 41       (1.0, 5000.0]               1                      0
# 42       (1.0, 5000.0]               1                      0
# 43       (1.0, 5000.0]               1                      0
# 44   (5000.0, 10000.0]               1                      1
# 45       (1.0, 5000.0]               1                      1
# 46  (15000.0, 20000.0]               0                      1
# 47   (5000.0, 10000.0]               1                      0
# 48       (1.0, 5000.0]               1                      0
# 49       (1.0, 5000.0]               1                      0
# 50       (1.0, 5000.0]               1                      0
#
#    credit_amount_discretizado installment_commitment_normalized
# 0               (1.0, 5000.0]                          1.666667
# 1           (5000.0, 10000.0]                          1.000000
# 2                         NaN                          1.666667
# 3                         NaN                          2.000000
# 4                         NaN                          2.000000
# 5                         NaN                          1.666667
# 6                         NaN                          1.333333
# 7                         NaN                          2.000000
# 8                         NaN                          2.000000
# 9                         NaN                          1.666667
# 10                        NaN                          1.666667
# 11                        NaN                          1.666667
# 12                        NaN                          1.666667
# 13                        NaN                          1.666667
# 14                        NaN                          1.333333
# 15                        NaN                          1.666667
# 16                        NaN                          2.000000
# 17                        NaN                          1.000000
# 18                        NaN                          1.666667
# 19                        NaN                          2.000000
# 20                        NaN                          2.000000
# 21                        NaN                          2.000000
# 22                        NaN                          2.000000
# 23                        NaN                          1.000000
# 24                        NaN                          2.000000
# 25                        NaN                          2.000000
# 26                        NaN                          1.333333
# 27                        NaN                          1.333333
# 28              (1.0, 5000.0]                          1.000000
# 29              (1.0, 5000.0]                          1.333333
# 30              (1.0, 5000.0]                          1.333333
# 31              (1.0, 5000.0]                          1.666667
# 32          (5000.0, 10000.0]                          2.000000
# 33              (1.0, 5000.0]                          2.000000
# 34              (1.0, 5000.0]                          1.333333
# 35              (1.0, 5000.0]                          1.666667
# 36          (5000.0, 10000.0]                          1.666667
# 37          (5000.0, 10000.0]                          2.000000
# 38              (1.0, 5000.0]                          2.000000
# 39              (1.0, 5000.0]                          1.000000
# 40              (1.0, 5000.0]                          2.000000
# 41              (1.0, 5000.0]                          2.000000
# 42              (1.0, 5000.0]                          1.000000
# 43              (1.0, 5000.0]                          1.333333
# 44          (5000.0, 10000.0]                          2.000000
# 45              (1.0, 5000.0]                          2.000000
# 46         (15000.0, 20000.0]                          1.000000
# 47          (5000.0, 10000.0]                          2.000000
# 48              (1.0, 5000.0]                          2.000000
# 49              (1.0, 5000.0]                          1.333333
# 50              (1.0, 5000.0]                          1.333333
#
# [51 rows x 27 columns]

# %%
#Pregunta 14

# %%
#Pregunta 15

# %%
#Pregunta 16

# %%
#Pregunta17

# %%
#Pregunta 18
